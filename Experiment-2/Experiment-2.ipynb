# %%
from matplotlib import image
from matplotlib import pyplot

#load image as pixel array
data=image.imread('elon.jpg')
print(data)
print(data.dtype)
print(data.shape)
#display the array of pixel as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# [[[115 118 127]
#   [115 118 127]
#   [115 118 127]
#   ...
#   [ 81  79  84]
#   [ 80  78  83]
#   [ 80  78  83]]
#
#  [[115 118 127]
#   [115 118 127]
#   [115 118 127]
#   ...
#   [ 80  78  83]
#   [ 79  77  82]
#   [ 79  77  82]]
#
#  [[115 118 127]
#   [115 118 127]
#   [115 118 127]
#   ...
#   [ 79  77  82]
#   [ 78  76  81]
#   [ 77  75  80]]
#
#  ...
#
#  [[ 24  15  16]
#   [ 24  15  16]
#   [ 24  15  16]
#   ...
#   [ 13   9  10]
#   [ 13   9  10]
#   [ 13   9  10]]
#
#  [[ 24  15  16]
#   [ 24  15  16]
#   [ 24  15  16]
#   ...
#   [ 14  10  11]
#   [ 14  10  11]
#   [ 14  10  11]]
#
#  [[ 24  15  16]
#   [ 24  15  16]
#   [ 24  15  16]
#   ...
#   [ 13   9  10]
#   [ 13   9  10]
#   [ 13   9  10]]]
# uint8
# (807, 564, 3)
